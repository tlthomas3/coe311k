# %% [markdown]
# I'm writing my first Jupyter notebook.

# %% [markdown]
# # Headings are cool!

# %% [markdown]
# ## Sub-headings are less cool.

# %% [markdown]
# [Links](https://www.google.com) work too!

# %%
print("Hello World")
# Out:
# Hello World
