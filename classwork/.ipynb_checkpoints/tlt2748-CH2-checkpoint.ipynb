# %% [markdown]
# # Challenge 2
#
# Find the binary counterpart of a base 10 integer.

# %%
num = 2025
binary = (f := lambda n: '1' if n % 2 else '0')(num)
while (num := num // 2) > 0:
    binary = f(num) + binary
print(binary)
# Out:
# 11111101001
