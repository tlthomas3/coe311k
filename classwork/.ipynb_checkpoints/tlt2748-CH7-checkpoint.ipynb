# %% [markdown]
# # Challenge 7
#
# Solve 3 sets of equations with Jacobi and Gauss-Seidel.

# %% [markdown]
# ## Setup

# %%
import numpy as np

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# ## Solving

# %%
max_iter = 50_000

A = np.array([
[0.582745, 0.48 , 0.10 , 0.  , 0.  ],
[0.48 , 1.044129, 0.46 , 0.10 , 0.  ],
[0.10 , 0.46 , 1.10431 , 0.44 , 0.10 ],
[0.  , 0.10 , 0.44 , 0.963889, 0.42 ],
[0.  , 0.  , 0.10 , 0.42 , 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

x1, n1 = jacobi(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.001, max_iter)
x2, n2 = gauss_seidel(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.000001, max_iter)

print("Case 1:")
print(f"      Jacobi ({n1}): ", x1)
print(f"Gauss-Seidel ({n2}): ", x2)

A = np.array([[1, 1], [1, 1.0001]], dtype=float)
b = np.array([1, 1], dtype=float)

x1, n1 = jacobi(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.001, max_iter)
x2, n2 = gauss_seidel(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.000001, max_iter)

print("\nCase 2:")
print(f"      Jacobi ({n1}): ", x1)
print(f"Gauss-Seidel ({n2}): ", x2)

A = np.array([[1, 1], [1, 1.0001]], dtype=float)
b = np.array([1, 1.0001], dtype=float)

x1, n1 = jacobi(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.001, max_iter)
x2, n2 = gauss_seidel(A, b, np.array([0, 0, 0, 0, 0], dtype=float), 0.000001, max_iter)

print("\nCase 3:")
print(f"      Jacobi ({n1}): ", x1)
print(f"Gauss-Seidel ({n2}): ", x2)
# Out:
# Case 1:
#       Jacobi (1814):  [1.00049732 1.00049758 1.00049761 1.00049748 1.00049714]
# Gauss-Seidel (20):  [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
#
# Case 2:
#       Jacobi (50000):  [0.91790474 0.         0.         0.         0.        ]
# Gauss-Seidel (1):  [1. 0. 0. 0. 0.]
#
# Case 3:
#       Jacobi (50000):  [0.         0.91790474 0.         0.         0.        ]
# Gauss-Seidel (46055):  [0.009999 0.990002 0.       0.       0.      ]
